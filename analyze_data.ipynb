# %%
polish_texts = {'advertisement': 7,
 'budget': 20,
 'email': 0,
 'file_folder': 6,
 'form': 0,
 'handwritten': 7,
 'invoice': 7,
 'letter': 0,
 'memo': 0,
 'news_article': 8,
 'pit37_v1': 400,
 'puob': 295,
 'presentation': 3,
 'questionnaire': 1,
 'resume': 0,
 'scientific_publication': 1,
 'scientific_report': 4,
 'specification': 1,
 'unod': 390,
 'umowa_o_dzielo': 373,
 'uss': 377}

english_texts = {'advertisement': 553,
 'budget': 532,
 'email': 562,
 'file_folder': 287,
 'form': 562,
 'handwritten': 598,
 'invoice': 545,
 'letter': 546,
 'memo': 555,
 'news_article': 495,
 'pit37_v1': 0,
 'puob': 0,
 'presentation': 573,
 'questionnaire': 549,
 'resume': 565,
 'scientific_publication': 573,
 'scientific_report': 577,
 'specification': 527,
 'unod': 0,
 'umowa_o_dzielo': 0,
 'uss': 0}

# %%
import matplotlib.pyplot as plt

keys = list(polish_texts.keys())
values_pl = list(polish_texts.values())
values_en = list(english_texts.values())

positions = range(len(keys))

plt.figure(figsize=(10, 6))

plt.bar(positions, values_pl, width=0.8, align='center', alpha=0.5, label='polski')
plt.bar(positions, values_en, width=0.8, align='center', alpha=0.5, label='angielski')

plt.xticks(positions, keys, rotation='vertical')


for i, value in enumerate(values_pl):
    plt.text(i, value + 5, str(value), ha='center')

for i, value in enumerate(values_en):
    plt.text(i, value + 5, str(value), ha='center')

plt.xlabel('Kategorie')
plt.ylabel('Liczność')
plt.title('Rodzaje Plików')

plt.legend()

plt.savefig('plots/rodzaje_plikow_ing.png')

plt.show()

# %%
other_texts = {'advertisement': 124,
 'budget': 125,
 'email': 15,
 'file_folder': 241,
 'form': 77,
 'handwritten': 182,
 'invoice': 109,
 'letter': 28,
 'memo': 10,
 'news_article': 67,
 'pit37_v1': 0,
 'puob': 0,
 'presentation': 160,
 'questionnaire': 42,
 'resume': 4,
 'scientific_publication': 27,
 'scientific_report': 96,
 'specification': 23,
 'unod': 0,
 'umowa_o_dzielo': 0,
 'uss': 0}

# %%
for key in polish_texts:
    print(key, round(polish_texts[key]/(english_texts[key]+polish_texts[key]+other_texts[key]),2))
# Out:
# advertisement 0.01
# budget 0.03
# email 0.0
# file_folder 0.01
# form 0.0
# handwritten 0.01
# invoice 0.01
# letter 0.0
# memo 0.0
# news_article 0.01
# pit37_v1 1.0
# puob 1.0
# presentation 0.0
# questionnaire 0.0
# resume 0.0
# scientific_publication 0.0
# scientific_report 0.01
# specification 0.0
# unod 1.0
# umowa_o_dzielo 1.0
# uss 1.0

# %%
polish_texts_adam = {0: 152,
 1: 98,
 2: 8,
 3: 142,
 4: 49,
 5: 241,
 6: 131,
 7: 19,
 8: 29,
 9: 95,
 10: 400,
 11: 295,
 12: 73,
 13: 64,
 14: 9,
 15: 43,
 16: 46,
 17: 53,
 18: 390,
 19: 373,
 20: 377}

english_texts_adam = {0: 303,
 1: 321,
 2: 525,
 3: 55,
 4: 448,
 5: 202,
 6: 352,
 7: 506,
 8: 518,
 9: 361,
 10: 0,
 11: 0,
 12: 377,
 13: 449,
 14: 552,
 15: 508,
 16: 441,
 17: 446,
 18: 0,
 19: 0,
 20: 0}

other_texts_adam = {0: 106,
 1: 135,
 2: 28,
 3: 334,
 4: 68,
 5: 145,
 6: 69,
 7: 24,
 8: 8,
 9: 38,
 10: 0,
 11: 0,
 12: 139,
 13: 38,
 14: 3,
 15: 18,
 16: 91,
 17: 30,
 18: 0,
 19: 0,
 20: 0}

# %%
for key in polish_texts_adam:
    print(key, round(polish_texts_adam[key]/(english_texts_adam[key]+polish_texts_adam[key]+other_texts_adam[key]),2))
# Out:
# 0 0.27
# 1 0.18
# 2 0.01
# 3 0.27
# 4 0.09
# 5 0.41
# 6 0.24
# 7 0.03
# 8 0.05
# 9 0.19
# 10 1.0
# 11 1.0
# 12 0.12
# 13 0.12
# 14 0.02
# 15 0.08
# 16 0.08
# 17 0.1
# 18 1.0
# 19 1.0
# 20 1.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined
